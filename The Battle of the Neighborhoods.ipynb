# %% [markdown]
# #The Battle of the Neighborhoods

# %% [markdown]
# ##Italian Vacation Planning

# %% [markdown]
# I love ice cream. I am always trying to find the best ice cream to enjoy. This week I want to use what I have learned in this course to find where is the best place in Italy to travel based on ice cream (gelato).

# %% [markdown]
# I will be comparing the cities of Rome, Florence, Venice, and Naples. I will be using the foursquare api in order to determine the number and location of all gelato shops in each city. I will then use this to recomend what city to visit and where in the city I should stay in order to be able to get the most of my gelato visit.

# %% [markdown]
# ##Data

# %% [markdown]
# I will be using the foursquare api in order to find the locations of all of the gelato shops in each city. I will also be mapping the locations and usuing a distnce formula in order to determine where I should find a place to stay.
